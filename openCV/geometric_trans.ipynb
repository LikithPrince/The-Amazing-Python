# %% [markdown]
# Geometric Transformations - Part 1: Scaling

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('Sales_Demo_Front.png')
resized=cv.resize(img,None,fx=2,fy=2,interpolation=cv.INTER_CUBIC)
# imgplot=plt.imshow(resized)

# %%
import matplotlib.pyplot as plt
# load image using cv2....and do processing.
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
# as opencv loads in BGR format by default, we want to show it in RGB.
plt.show()

# %%
plt.imshow(cv.cvtColor(resized, cv.COLOR_BGR2RGB))
# as opencv loads in BGR format by default, we want to show it in RGB.
plt.show()

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('images/Sales_Demo_Front.png')
resized=cv.resize(img,None,fx=0.5,fy=0.5,interpolation=cv.INTER_CUBIC)
plt.imshow(cv.cvtColor(resized, cv.COLOR_BGR2RGB))
# as opencv loads in BGR format by default, we want to show it in RGB.
plt.show()
# img_save=cv.imwrite("resized_image.png",resized)

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt


img = cv.imread('images/Sales_Demo_Front.png',0)
img = cv.medianBlur(img,5)
ret,th1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
th2 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_MEAN_C,cv.THRESH_BINARY,11,2)
th3 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,cv.THRESH_BINARY,11,2)
titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]
for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray',vmin=0,vmax=255)
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt


img = cv.imread('images/Sales_Demo_Front.png',0)
# global thresholding
thresh_value_1,thresh_img_1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
# Otsu's thresholding
thresh_value_2,thresh_img_2  = cv.threshold(img,0,255,cv.THRESH_BINARY+cv.THRESH_OTSU)
# Otsu's thresholding after Gaussian filtering
blur = cv.GaussianBlur(img,(5,5),0)
thresh_value_3,thresh_img_3  = cv.threshold(blur,0,255,cv.THRESH_BINARY+cv.THRESH_OTSU)
# plot all the images and their histograms
images = [img, 0, thresh_img_1, img, 0, thresh_img_2, blur, 0, thresh_img_3]
titles = ['Original Noisy Image','Histogram','Global Thresholding (v=127)',
            'Original Noisy Image','Histogram',"Otsu's Thresholding",
            'Gaussian filtered Image','Histogram',"Otsu's Thresholding"]
for i in range(3):
    plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
    plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
    plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2],'gray')
    plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])
plt.show()

# %%
from matplotlib import pyplot as plt
import cv2

img=cv2.imread("images/Sales_Demo_Front.png")
# cv2.imshow("Original image",img)
# plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.hist(img.ravel(),256,[0,256])
plt.show()

# %%
from matplotlib import pyplot as plt
import cv2

img=cv2.imread("images/Sales_Demo_Front.png",0)
# cv2.imshow("Original image",img)
# plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.hist(img.ravel(),256,[0,256])
plt.show()

# %%
from matplotlib import pyplot as plt
import cv2

img=cv2.imread("images/Sales_Demo_Front.png",0)
# color_img=cv2.imread("images/Sales_Demo_Front.png")
equailzed=cv2.equalizeHist(img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# plt.hist(img.ravel(),256,[0,256])
plt.xticks([]),plt.yticks([])
plt.show()
plt.imshow(cv2.cvtColor(equailzed, cv2.COLOR_BGR2RGB))
plt.xticks([]),plt.yticks([])
plt.show()
