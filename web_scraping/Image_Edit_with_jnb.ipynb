# %%
from PIL import Image

img=Image.open(r'C:/Users/LikithP/OneDrive - Ennoventure Inc/Documents/Projects/Hologram Code/Patanjali Hologram/Patanjali_Design_png/Patanjali_Encryption_Un_encrypted.png')
print(img.size)
# Out:
# (390, 190)

# %%
output=img.crop((0,0,214,190))
output.show()

# %%
output1=output.save('C:/Users/LikithP/OneDrive - Ennoventure Inc/Documents/Projects/Hologram Code/Patanjali Hologram/Patanjali_Design_cropped_png/Patanjali_Encryption_Un_encrypted_crop.png')
